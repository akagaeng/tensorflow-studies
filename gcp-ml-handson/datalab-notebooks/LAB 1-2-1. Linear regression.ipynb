# %% [markdown]
# ## LAB 1-2. Linear regression

# %%
import numpy as np
import matplotlib.pyplot as plt

num_points = 200
vectors_set = []
for i in range(num_points):
  x = np.random.normal(5,5)+15
  #y = (x-100)*0.90 + np.random.random_integers(-4,4)
  y =  x*1000+ (np.random.normal(0,3))*1000
  vectors_set.append([x,y])
  
x_data = [v[0] for v in vectors_set ]
y_data = [v[1] for v in vectors_set ]

plt.plot(x_data,y_data,'ro')
plt.ylim([0,40000])
plt.xlim([5,35])
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import tensorflow as tf

W = tf.Variable(tf.random_uniform([1],-1.0,1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

loss = tf.reduce_mean(tf.square(y-y_data))
optimizer = tf.train.GradientDescentOptimizer(0.0015)
train = optimizer.minimize(loss)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(10):
  _,w_val,b_val,loss_val=sess.run([train,W,b,loss])
  print(w_val,b_val,loss_val)
  
  plt.plot(x_data,y_data,'ro')
  plt.plot(x_data,w_val*x_data + b_val)
  plt.xlabel('x')
  plt.ylabel('y')
  plt.legend()
  plt.show()
# Out:
# No handles with labels found to put in legend.
# [1377.119] [62.19615] 469382560.0
# No handles with labels found to put in legend.
# [851.1492] [38.4076] 77274940.0
# No handles with labels found to put in legend.
# [1051.9207] [47.4405] 20143092.0
# [975.2857] [43.94504] 11818726.0
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# [1004.5404] [45.23183] 10605825.0
# No handles with labels found to put in legend.
# [993.3757] [44.693184] 10429100.0
# No handles with labels found to put in legend.
# [997.6395] [44.851337] 10403347.0
# No handles with labels found to put in legend.
# [996.0141] [44.743523] 10399594.0
# No handles with labels found to put in legend.
# [996.63666] [44.73724] 10399048.0
# [996.40125] [44.692215] 10398968.0
# No handles with labels found to put in legend.
